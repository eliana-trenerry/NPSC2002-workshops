# %% [markdown]
# <a href="https://colab.research.google.com/github/eliana-trenerry/NPSC2002-workshops/blob/main/Week_01_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NPSC2002: Space Exploration - Week 1 Workshop
# ## Introduction to Jupyter Notebooks, GitHub, and Google Colab
#
# **Welcome to NPSC2002!**
#
# This is your first workshop notebook. Today you will:
# 1. Learn what Jupyter notebooks are and how they work
# 2. Set up your GitHub account and fork this repository
# 3. Connect Google Colab to your GitHub account
# 4. Learn basic Python programming in notebooks
# 5. Understand how workshops will work throughout the semester
# 6. Complete a space-themed introductory exercise
#
# **This workshop is NOT assessed** - it's here to help you get comfortable with the technology!
#
# ---

# %% [markdown]
# ## Part 1: What is a Jupyter Notebook?
#
# You're reading one right now! A Jupyter notebook is an interactive document that combines:
# - **Text** (like this explanation)
# - **Code** (Python programs that run right here)
# - **Outputs** (results from your code - numbers, graphs, images)
#
# Notebooks are organized into **cells**. There are two main types:
# 1. **Markdown cells** - contain formatted text (like this cell)
# 2. **Code cells** - contain Python code that you can run
#
# ### Try it yourself!
#
# The cell below is a **code cell**. To run it:
# - Click on the cell to select it
# - Press **Shift+Enter** (or click the ▶ play button if you're in Google Colab)
#
# Try it now:

# %%
# This is a code cell - anything after # is a comment
# Run this cell to see a welcome message!

print("Welcome to NPSC2002!")
print("You just ran your first Python code!")
# Out:
# Welcome to NPSC2002!
# You just ran your first Python code!

# %% [markdown]
# **What happened?**
#
# When you ran that cell, Python executed the `print()` commands and displayed the output below the cell.
#
# ### Code cells remember what you've done
#
# Run the next two cells in order:

# %%
# Run this cell first - it stores a value
spacecraft_name = "Voyager 1"
launch_year = 1977

# %%
# Now run this cell - it uses the values from above
print(f"{spacecraft_name} launched in {launch_year}")
print(f"It has been exploring space for {2026 - launch_year} years!")
# Out:
# Voyager 1 launched in 1977
# It has been exploring space for 49 years!

# %% [markdown]
# Notice how the second cell "remembered" the variables from the first cell. This is because the notebook maintains a **kernel** - a running Python session that keeps track of everything you've done.
#
# ---

# %% [markdown]
# ## Part 2: Setting Up Your GitHub Account
#
# GitHub is a platform for storing and sharing code. You'll use it to:
# - Keep your own copy of all workshop notebooks
# - Save your work automatically
# - Allow the lecturer to access your completed workshops for assessment
#
# ### Steps to set up GitHub:
#
# 1. **Create a GitHub account** (if you don't have one):
#    - Go to [github.com](https://github.com)
#    - Click "Sign up"
#    - Use any email address you prefer
#    - Choose a professional username (e.g., firstname-lastname)
#
# 2. **Fork the NPSC2002 workshop repository**:
#    - Your lecturer will provide the repository URL (something like: `github.com/lecturer-name/NPSC2002-workshops`)
#    - Navigate to that URL while logged into GitHub
#    - Click the **"Fork"** button in the top-right corner
#    - This creates YOUR OWN copy of all workshop materials
#
# 3. **Record your details**:
#    - Once you've forked the repository, copy the URL of YOUR fork
#    - It will look like: `github.com/YOUR-USERNAME/NPSC2002-workshops`
#    - **Write this URL down** - you'll need it!
#
# ### ✏️ ACTION REQUIRED:
#
# **In the cell below, replace `"YOUR-GITHUB-USERNAME"` with your actual GitHub username, then run the cell:**

# %%
# Replace this with YOUR GitHub username
my_github_username = "eliana-trenerry"

# Run this cell to see your repository URL
my_repo_url = f"https://github.com/{my_github_username}/NPSC2002-workshops"
print(f"Your forked repository URL is: {my_repo_url}")
print(f"\nBookmark this URL - you'll use it all semester!")
# Out:
# Your forked repository URL is: https://github.com/eliana-trenerry/NPSC2002-workshops
#
# Bookmark this URL - you'll use it all semester!

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3: Opening This Notebook in Google Colab
#
# Google Colab is a free cloud service that lets you run Jupyter notebooks without installing anything on your computer.
#
# ### If you're reading this in Google Colab already:
# Great! You've already completed this step. Skip to Part 4.
#
# ### If you're reading this on GitHub or locally:
#
# 1. **Go to** [colab.research.google.com](https://colab.research.google.com)
# 2. **Sign in** with your Google account (use your Google account)
# 3. **Open from GitHub**:
#    - Click "File" → "Open notebook"
#    - Click the "GitHub" tab
#    - Enter your forked repository URL (from the previous step)
#    - Select this notebook: `Week_01_Introduction.ipynb`
#
# ### Connecting Colab to GitHub (First time only):
#
# To save your work back to GitHub from Colab:
#
# 1. In Colab, click **"File" → "Save a copy in GitHub"**
# 2. You'll be asked to authorize Google Colab to access your GitHub
# 3. Click **"Authorize googlecolab"**
# 4. Select your forked repository
# 5. Add a commit message (e.g., "Completed Week 1 introduction")
# 6. Click **"OK"**
#
# **From now on**, use **"File" → "Save a copy in GitHub"** whenever you want to save your work!
#
# ---

# %% [markdown]
# ## Part 4: Python Basics for Complete Beginners
#
# Don't worry if you've never programmed before! This section covers everything you need.
#
# ### 4.1 Variables: Storing Information
#
# Variables are like labeled boxes that store values:

# %%
# Storing numbers
mars_distance_km = 225_000_000  # Distance from Earth to Mars (avg)
speed_of_light = 299_792  # km/s

# Storing text (called "strings")
mission_name = "Perseverance"
planet = "Mars"

# You can display values with print()
print(f"The {mission_name} rover is exploring {planet}")
print(f"Average distance to {planet}: {mars_distance_km:,} km")
# Out:
# The Perseverance rover is exploring Mars
# Average distance to Mars: 225,000,000 km

# %% [markdown]
# ### 4.2 Doing Math
#
# Python can be used as a powerful calculator:

# %%
# Basic operations
total_mass = 1000 + 500  # Addition
fuel_remaining = 1000 - 300  # Subtraction
orbital_period = 90 * 60  # Multiplication (90 minutes in seconds)
average_speed = 1000 / 10  # Division

# Powers (like for rocket equation!)
escape_velocity_squared = 11.2 ** 2

print(f"Spacecraft mass: {total_mass} kg")
print(f"Fuel remaining: {fuel_remaining} kg")
print(f"Orbital period: {orbital_period} seconds")
print(f"Escape velocity squared: {escape_velocity_squared} km²/s²")
# Out:
# Spacecraft mass: 1500 kg
# Fuel remaining: 700 kg
# Orbital period: 5400 seconds
# Escape velocity squared: 125.43999999999998 km²/s²

# %% [markdown]
# ### 4.3 Lists: Storing Multiple Values
#
# Lists let you store many related values together:

# %%
# A list of planets
inner_planets = ["Mercury", "Venus", "Earth", "Mars"]

# A list of distances from the Sun (in AU)
distances_from_sun = [0.39, 0.72, 1.0, 1.52]

# Accessing items (counting starts at 0!)
print(f"First planet: {inner_planets[0]}")
print(f"Fourth planet: {inner_planets[3]}")
print(f"Mars is {distances_from_sun[3]} AU from the Sun")

# How many items?
print(f"\nNumber of inner planets: {len(inner_planets)}")
# Out:
# First planet: Mercury
# Fourth planet: Mars
# Mars is 1.52 AU from the Sun
#
# Number of inner planets: 4

# %% [markdown]
# ### 4.4 Loops: Doing Things Repeatedly
#
# Loops let you repeat actions without writing the same code over and over:

# %%
# Loop through all planets
print("The inner planets:")
for planet in inner_planets:
    print(f"  - {planet}")

print("\nPlanets with their distances:")
for i in range(len(inner_planets)):
    print(f"  - {inner_planets[i]}: {distances_from_sun[i]} AU from Sun")
# Out:
# The inner planets:
#   - Mercury
#   - Venus
#   - Earth
#   - Mars
#
# Planets with their distances:
#   - Mercury: 0.39 AU from Sun
#   - Venus: 0.72 AU from Sun
#   - Earth: 1.0 AU from Sun
#   - Mars: 1.52 AU from Sun

# %% [markdown]
# ### 4.5 Libraries: Using Pre-written Code
#
# Python has thousands of libraries with useful functions. We'll use several throughout the course:

# %%
# Import the math library
import math

# Use functions from the library
radius = 6371  # Earth's radius in km
circumference = 2 * math.pi * radius

print(f"Earth's circumference: {circumference:.0f} km")
print(f"Square root of 16: {math.sqrt(16)}")
# Out:
# Earth's circumference: 40030 km
# Square root of 16: 4.0

# %% [markdown]
# ### 4.6 Making Graphs
#
# We'll frequently visualize data using matplotlib:

# %%
import matplotlib.pyplot as plt

# Data: planet distances from the Sun
planets = ["Mercury", "Venus", "Earth", "Mars"]
distances = [0.39, 0.72, 1.0, 1.52]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(planets, distances, color=['gray', 'orange', 'blue', 'red'])
plt.ylabel('Distance from Sun (AU)')
plt.title('Inner Solar System: Distances from the Sun')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Part 5: How Workshops Will Work This Semester
#
# ### Workshop Structure
#
# Each week (Weeks 2-11), you'll receive a notebook like this one covering that week's topic:
#
# Topics will cover:
# - Rocket physics and orbital mechanics
# - Mission data analysis
# - Spacecraft payload design
# - Remote sensing and Earth observation
# - Technology spin-offs and innovation
# - Future exploration planning
#
# ### Your Workflow
#
# 1. **Before the workshop**: The notebook will be added to the main repository
# 2. **At the start of workshop**:
#    - Open Google Colab
#    - Go to File → Open notebook → GitHub
#    - Select YOUR forked repository
#    - Open that week's notebook
# 3. **During the workshop**:
#    - Work through the exercises
#    - Write code, run calculations, analyze data
#    - Ask questions when you're stuck!
# 4. **Save your work**:
#    - File → Save a copy in GitHub
#    - Add a commit message (e.g., "Completed Week 2 exercises")
#    - Click OK
# 5. **That's it!** No formal submission needed.
#
# ### Assessment
#
# - You choose **4 out of 8** workshop notebooks (Weeks 2-11) to be assessed
# - Only work saved **during the workshop session** will be marked
# - The lecturer will access your GitHub repository directly to review your work
# - Your mark is the average of your 4 chosen workshops
#
# ### Tips for Success
#
# ✅ **Save regularly** - Use "File → Save a copy in GitHub" every 15-20 minutes
#
# ✅ **Don't delete cells** - Even if you make a mistake, keep your work visible
#
# ✅ **Add comments** - Explain your thinking with `# comments`
#
# ✅ **Run all cells in order** - Before saving, run all cells from top to bottom
#
# ✅ **Ask questions** - That's what workshop time is for!
#
# ❌ **Don't wait until the last minute to save** - Network issues happen!
#
# ❌ **Don't work on the wrong repository** - Make sure you're in YOUR fork, not the main repo
#
# ---

# %% [markdown]
# ## Interlude: NASA's Deep Space Network Right Now
#
# Before we start our exercise, let's see what NASA is actually doing right now!
#
# ### 🛰️ Check out the Deep Space Network (DSN)
#
# NASA uses a global network of giant radio antennas to communicate with spacecraft throughout the solar system. You can see what's happening in real-time:
#
# **👉 Visit: [https://eyes.nasa.gov/apps/dsn-now/](https://eyes.nasa.gov/apps/dsn-now/)**
#
# Take a few minutes to explore:
# - Which spacecraft are currently being tracked?
# - Where are the DSN stations located? (Look for Goldstone, Madrid, and Canberra)
# - How far away are the spacecraft?
# - What's the signal delay?
#
# This is the real infrastructure that enables space exploration! The delays you'll calculate in the next exercise are the same delays mission operators deal with every day.
#
# ---

# %% [markdown]
# ## Part 6: Practice Exercise - Exploring Space Mission Distances
#
# Let's put everything together with a space-themed exercise!
#
# ### Scenario
#
# You're planning communication with several spacecraft exploring the solar system. Radio signals travel at the speed of light, but even at that incredible speed, there's a noticeable delay when communicating with distant spacecraft.
#
# ### Your Task
#
# Calculate the communication delay (round-trip) for several spacecraft at their current distances from Earth.
#
# **Run the cell below to see the spacecraft data:**

# %%
# Spacecraft and their approximate distances from Earth (as of 2026)
spacecraft_data = {
    "ISS": 408,                    # km
    "Moon (Apollo site)": 384_400,  # km
    "Mars Perseverance": 225_000_000,  # km (varies with orbital position)
    "Voyager 1": 24_000_000_000,   # km (in interstellar space!)
}

# Speed of light
speed_of_light_km_per_sec = 299_792  # km/s

print("Spacecraft distances from Earth:")
for spacecraft, distance in spacecraft_data.items():
    print(f"  {spacecraft}: {distance:,} km")
# Out:
# Spacecraft distances from Earth:
#   ISS: 408 km
#   Moon (Apollo site): 384,400 km
#   Mars Perseverance: 225,000,000 km
#   Voyager 1: 24,000,000,000 km

# %% [markdown]
# ### Exercise 6.1: Calculate One-Way Signal Time
#
# **Calculate how long it takes for a signal to reach the ISS from Earth:**
#
# Formula: `time = distance / speed`
#
# Fill in the code below:

# %%
# Get the distance to ISS
iss_distance = spacecraft_data["ISS"]

# Calculate the time (in seconds)
# YOUR CODE HERE - calculate: iss_distance / speed_of_light_km_per_sec
signal_time_to_iss = iss_distance/speed_of_light_km_per_sec

# Display the result
print(f"Signal takes {signal_time_to_iss:.4f} seconds to reach the ISS")
print(f"That's {signal_time_to_iss * 1000:.2f} milliseconds!")
# Out:
# Signal takes 0.0014 seconds to reach the ISS
# That's 1.36 milliseconds!

# %% [markdown]
# ### Exercise 6.1b: ISS at Maximum Distance
#
# **The ISS orbits at approximately 408 km altitude, but that's the closest it gets!**
#
# When the ISS is on the opposite side of Earth from you, the signal has to travel:
# - Up to the ISS (408 km)
# - PLUS across Earth's diameter
#
# Earth's radius is approximately 6,371 km.
#
# **Calculate the maximum distance to the ISS and the signal time at that distance:**

# %%
# Earth's radius
earth_radius_km = 6371

# ISS orbital altitude
iss_altitude = 408

# YOUR CODE HERE:
# Calculate the maximum distance when ISS is on the opposite side of Earth
# Hint: You need to go up to orbit, across Earth's diameter, then up to orbit again
# Maximum distance = ?
max_iss_distance = 2*6317 + 408 + 408

# Calculate signal time at maximum distance
# YOUR CODE HERE
max_signal_time = max_iss_distance / speed_of_light_km_per_sec

# Compare with minimum distance
min_iss_distance = iss_altitude
min_signal_time = min_iss_distance / speed_of_light_km_per_sec

print(f"ISS closest distance: {min_iss_distance:,} km")
print(f"ISS furthest distance: {max_iss_distance:,} km")
print(f"\nSignal time (closest): {min_signal_time*1000:.2f} milliseconds")
print(f"Signal time (furthest): {max_signal_time*1000:.2f} milliseconds")
print(f"\nDifference: {(max_signal_time - min_signal_time)*1000:.2f} milliseconds")
# Out:
# ISS closest distance: 408 km
# ISS furthest distance: 13,450 km
#
# Signal time (closest): 1.36 milliseconds
# Signal time (furthest): 44.86 milliseconds
#
# Difference: 43.50 milliseconds

# %% [markdown]
# ### Exercise 6.2: Calculate Round-Trip Times for All Spacecraft
#
# **Now calculate the round-trip delay for all spacecraft**
#
# (Signal goes to spacecraft, then the reply comes back = double the one-way time)
#
# Complete the code below:

# %%
print("Round-trip communication delays:\n")

# Loop through all spacecraft
for spacecraft, distance in spacecraft_data.items():
    # Calculate one-way time
    # YOUR CODE HERE

    one_way_time = distance/speed_of_light_km_per_sec

    # Calculate round-trip time (multiply by 2)
    # YOUR CODE HERE
    round_trip_time = one_way_time*2

    # Display in appropriate units
    if round_trip_time < 1:
        print(f"{spacecraft:20s}: {round_trip_time*1000:.2f} milliseconds")
    elif round_trip_time < 60:
        print(f"{spacecraft:20s}: {round_trip_time:.2f} seconds")
    elif round_trip_time < 3600:
        print(f"{spacecraft:20s}: {round_trip_time/60:.2f} minutes")
    else:
        print(f"{spacecraft:20s}: {round_trip_time/3600:.2f} hours")
# Out:
# Round-trip communication delays:
#
# ISS                 : 2.72 milliseconds
# Moon (Apollo site)  : 2.56 seconds
# Mars Perseverance   : 25.02 minutes
# Voyager 1           : 44.48 hours

# %% [markdown]
# ### Exercise 6.3: Visualize the Data
#
# **Create a bar chart showing the round-trip times**
#
# We'll help you get started:

# %%
import matplotlib.pyplot as plt

# Calculate round-trip times and store them
spacecraft_names = []
round_trip_times_hours = []

for spacecraft, distance in spacecraft_data.items():
    one_way_time = distance / speed_of_light_km_per_sec
    # Calculate round-trip time in hours directly
    round_trip_time_in_hours = (one_way_time * 2) / 3600

    spacecraft_names.append(spacecraft)
    round_trip_times_hours.append(round_trip_time_in_hours)

# Create the plot
plt.figure (figsize=(12,6))

# Create a bar chart
plt.bar(spacecraft_names, round_trip_times_hours, color=['gray', 'orange', 'blue', 'red'])

# Set the y-axis to a logarithmic scale
plt.yscale('log')

# Add labels and title
plt.ylabel('Round-trip signal time (hours, log scale))', fontsize=12)
plt.xlabel('Spacecraft', fontsize=12)
plt.title('Communication Delays with Spacecraft in the Solar System', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Using the Mathematical Logarithm (`math.log`)
#
# To perform mathematical logarithm calculations, you'll use the `math` module. Here's how:
#
# *   **Natural Logarithm (base e):** `math.log(x)`
# *   **Logarithm with a specific base:** `math.log(x, base)`
# *   **Base-10 Logarithm:** `math.log10(x)` (a shorthand for `math.log(x, 10)`)

# %%
import math

# Calculate the natural logarithm of 10
natural_log = math.log(10)
print(f"Natural logarithm of 10: {natural_log:.4f}")

# Calculate the logarithm of 100 with base 10
log_base_10 = math.log(100, 10)
print(f"Logarithm of 100 (base 10): {log_base_10:.4f}")

# Alternatively, use math.log10 for base 10
log10_alternative = math.log10(100)
print(f"Log10 of 100: {log10_alternative:.4f}")

# Calculate the logarithm of 8 with base 2
log_base_2 = math.log(8, 2)
print(f"Logarithm of 8 (base 2): {log_base_2:.4f}")
# Out:
# Natural logarithm of 10: 2.3026
# Logarithm of 100 (base 10): 2.0000
# Log10 of 100: 2.0000
# Logarithm of 8 (base 2): 3.0000

# %% [markdown]
# ### Exercise 6.4: Reflection Questions
#
# **Answer these questions in the markdown cell below:**
#
# 1. Why does Voyager 1 have such a long communication delay?
# 2. How does this delay affect mission operations for Mars rovers?
# 3. What does this tell you about the challenges of controlling spacecraft in real-time?
#
# **Double-click this cell to edit it and type your answers:**
#
# **Answer 1:** Voyager 1 is the furthest spacecraft from Earth and it takes the radiowaves the longest time to travel the vast distance.
#
# **Answer 2:** A delay in communicating with the Mars rovers can affect mission operations as the rovers cannot be controlled in real-time. This can be a limitation as conditions change and rover operations have to be pre-programmed.
#
# **Answer 3:** There are major challenges in controlling spacecraft in real-time. Spacecraft need to be controlled with pre-programmed tasks, meaning scientists have to predict the ever-changing, and unpredictable conditions. This also introduces the idea of using AI and autonomous control of the spacecraft to combat the delay. This raises new ethical and scientific dilemmas.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 7: Saving Your Work
#
# ### Final Steps
#
# Before you finish today's workshop:
#
# 1. **Run all cells from top to bottom**:
#    - In Colab: Runtime → Run all
#    - This ensures everything works in order
#
# 2. **Save to GitHub**:
#    - File → Save a copy in GitHub
#    - Repository: YOUR forked repository
#    - File path: Week_01_Introduction.ipynb
#    - Commit message: "Completed Week 1 introduction workshop"
#    - Click OK
#
# 3. **Verify it saved**:
#    - Go to your GitHub repository in a web browser
#    - You should see the updated file with a timestamp
#
# 4. **View your commit history**:
#    - On your repository page, click on the notebook filename
#    - Click **"History"** button (top right, looks like a clock icon)
#    - You'll see all your saves (commits) with timestamps
#    - Click on any commit to see exactly what changed
#    - **This is how your lecturer will verify you completed work during workshop time!**
#
# Try it now: After saving this notebook, go check your commit history!
#
# ### Record Your GitHub Username
#
# **Run this cell and make sure it shows YOUR GitHub username:**

# %%
# This should show YOUR username from Part 2
print(f"My GitHub username: {my_github_username}")
print(f"My repository: {my_repo_url}")
print("\n✓ Make sure this is YOUR username, not 'YOUR-GITHUB-USERNAME'!")
# Out:
# My GitHub username: eliana-trenerry
# My repository: https://github.com/eliana-trenerry/NPSC2002-workshops
#
# ✓ Make sure this is YOUR username, not 'YOUR-GITHUB-USERNAME'!

# %% [markdown]
# ---

# %% [markdown]
# ## Congratulations! 🎉
#
# You've completed the Week 1 introduction workshop! You now know how to:
#
# ✅ Work with Jupyter notebooks
#
# ✅ Use GitHub to store your work
#
# ✅ Open and save notebooks in Google Colab
#
# ✅ Write basic Python code
#
# ✅ Create visualizations
#
# ✅ Calculate space mission parameters
#
# ### Next Week
#
# Week 2's workshop will dive into real space exploration topics with hands-on data analysis and calculations.
#
# ### Questions?
#
# If you have any questions about:
# - GitHub setup
# - Google Colab
# - Python basics
# - How workshops will work
#
# Ask your lecturer or tutors now!
#
# ### Remember
#
# 📌 Bookmark your GitHub repository URL
#
# 📌 You'll choose 4 out of 8 workshops (Weeks 2-7, 11, 12) for assessment
#
# 📌 Save your work regularly during workshops
#
# 📌 Week 1 is NOT assessed - it's just practice!
#
# ---
#
# **See you next week for rocket science! 🚀**

# %% [markdown]
# Want to dive deeper into Jupyter Notebooks? **"File" → "Open Notebook" → "Examples"**
